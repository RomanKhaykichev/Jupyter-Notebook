# %% [markdown]
# ### Модификация таблиц с Pandas

# %%
import pandas as pd

# %% [markdown]
# Будем работать с датасетом по оттоку клиентов из банка https://www.kaggle.com/datasets/shubh0799/churn-modelling,<br> но датасет из себя будет представлять две таблицы:
#
# 1. Личные данные клиента
#
# - CustomerId - Уникальный идентификатор клиента
# - Surname - Фамилия клиента
# - Geography - Из какой страны клиент
# - Gender - Пол клиента
# - Age - Возраст клиента
# - EstimatedSalary - Предположительная зарплата клиента
#
# 2. Данные по поведению клиента в банке
#
# - CustomerId - Уникальный идентификатор клиента
# - CustomerId - Уникальный идентификатор клиента
# - Tenure - Сколько лет человек является клиентом банка
# - Balance - Баланс счета
# - NumOfProducts - Количество открытых продуктов
# - HasCrCard - Есть ли у клиента кредитная карта
# - IsActiveMember - Является ли клиент активные участником
# - Exited - Уйдет ли человек в отток

# %%
users = pd.read_csv('../Seminar_2/Churn_Modelling.csv', sep=",")
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
users.shape
# Out:
# (10000, 14)

# %% [markdown]
# ### Создание новых признаков

# %%
users['new_feature'] = 0
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature
# 0        101348.88       1            0
# 1        112542.58       0            0
# 2        113931.57       1            0
# 3         93826.63       0            0
# 4         79084.10       0            0

# %%
users['Age (days)'] = users['Age'] * 365
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)
# 0        101348.88       1            0       15330
# 1        112542.58       0            0       14965
# 2        113931.57       1            0       15330
# 3         93826.63       0            0       14235
# 4         79084.10       0            0       15695

# %%
for i, row in users.iloc[:2].iterrows():
    print(row)
    print('__' * 30)
# Out:
# RowNumber                  1
# CustomerId          15634602
# Surname             Hargrave
# CreditScore              619
# Geography             France
# Gender                Female
# Age                       42
# Tenure                     2
# Balance                  0.0
# NumOfProducts              1
# HasCrCard                  1
# IsActiveMember             1
# EstimatedSalary    101348.88
# Exited                     1
# new_feature                0
# Age (days)             15330
# Name: 0, dtype: object
# ____________________________________________________________
# RowNumber                  2
# CustomerId          15647311
# Surname                 Hill
# CreditScore              608
# Geography              Spain
# Gender                Female
# Age                       41
# Tenure                     1
# Balance             83807.86
# NumOfProducts              1
# HasCrCard                  0
# IsActiveMember             1
# EstimatedSalary    112542.58
# Exited                     0
# new_feature                0
# Age (days)             14965
# Name: 1, dtype: object
# ____________________________________________________________

# %%
age_days = []

for i, row in users.iterrows():
    age_days.append(row['Age'] * 365)

age_days[:10]
# Out:
# [15330, 14965, 15330, 14235, 15695, 16060, 18250, 10585, 16060, 9855]

# %%
users['Age (days) 2'] = age_days
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695

# %%
def age_to_days(x):
    return x * 365

users['Age (days) 3'] = users['Age'].apply(age_to_days)
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695
#
#    Age (days) 3
# 0         15330
# 1         14965
# 2         15330
# 3         14235
# 4         15695

# %%
import time
from tqdm import tqdm
tqdm.pandas()


def age_to_days(x):
    time.sleep(0.001)
    return x * 365

users['Age'].progress_apply(age_to_days)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[128], line 2
#       1 import time
# ----> 2 from tqdm import tqdm
#       3 tqdm.pandas()
#       6 def age_to_days(x):
#
# ModuleNotFoundError: No module named 'tqdm'

# %% [markdown]
# ### Удаление признаков

# %%
users.drop(columns='new_feature')
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695
#
#    Age (days) 3
# 0         15330
# 1         14965
# 2         15330
# 3         14235
# 4         15695

# %%
users = users.drop(columns='new_feature')
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age (days)  Age (days) 2  Age (days) 3
# 0        101348.88       1       15330         15330         15330
# 1        112542.58       0       14965         14965         14965
# 2        113931.57       1       15330         15330         15330
# 3         93826.63       0       14235         14235         14235
# 4         79084.10       0       15695         15695         15695

# %%
users['new_feature'] = 0

# %%
users.drop(columns='new_feature', inplace=True)
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Age (days)  Age (days) 2  Age (days) 3
# 0        101348.88       1       15330         15330         15330
# 1        112542.58       0       14965         14965         14965
# 2        113931.57       1       15330         15330         15330
# 3         93826.63       0       14235         14235         14235
# 4         79084.10       0       15695         15695         15695

# %%
users.drop(columns=['Age (days)', 'Age (days) 2', 'Age (days) 3'], inplace=True)
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ### Изменение существующих признаков

# %% [markdown]
# .loc

# %%
users['target'] = 0
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695
#
#    Age (days) 3  target
# 0         15330       0
# 1         14965       0
# 2         15330       0
# 3         14235       0
# 4         15695       0

# %%
users.loc[users['Geography'] == 'France']
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 6             7    15592531   Bartlett          822    France    Male   50
# 8             9    15792365         He          501    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 6          7       0.00              2          1               1
# 8          4  142051.07              2          0               1
# ...      ...        ...            ...        ...             ...
# 9994       2       0.00              2          0               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0           101348.88       1            0       15330         15330
# 2           113931.57       1            0       15330         15330
# 3            93826.63       0            0       14235         14235
# 6            10062.80       0            0       18250         18250
# 8            74940.50       0            0       16060         16060
# ...               ...     ...          ...         ...           ...
# 9994        167773.55       0            0       10585         10585
# 9995         96270.64       0            0       14235         14235
# 9996        101699.77       0            0       12775         12775
# 9997         42085.58       1            0       13140         13140
# 9999         38190.78       0            0       10220         10220
#
#       Age (days) 3  target
# 0            15330       0
# 2            15330       0
# 3            14235       0
# 6            18250       0
# 8            16060       0
# ...            ...     ...
# 9994         10585       0
# 9995         14235       0
# 9996         12775       0
# 9997         13140       0
# 9999         10220       0
#
# [5014 rows x 19 columns]

# %%
users.loc[users['Geography'] == 'France', 'target']
# Out:
# 0       0
# 2       0
# 3       0
# 6       0
# 8       0
#        ..
# 9994    0
# 9995    0
# 9996    0
# 9997    0
# 9999    0
# Name: target, Length: 5014, dtype: int64

# %%
users[users['Geography'] == 'France']['target'] = 1
users.head()
# Out:
# C:\Users\mrrom\AppData\Local\Temp\ipykernel_9752\1082220520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users[users['Geography'] == 'France']['target'] = 1
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695
#
#    Age (days) 3  target
# 0         15330       0
# 1         14965       0
# 2         15330       0
# 3         14235       0
# 4         15695       0

# %%
users.loc[users['Geography'] == 'France','target'] = 1
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_feature  Age (days)  Age (days) 2  \
# 0        101348.88       1            0       15330         15330
# 1        112542.58       0            0       14965         14965
# 2        113931.57       1            0       15330         15330
# 3         93826.63       0            0       14235         14235
# 4         79084.10       0            0       15695         15695
#
#    Age (days) 3  target
# 0         15330       1
# 1         14965       0
# 2         15330       1
# 3         14235       1
# 4         15695       0

# %% [markdown]
# .replace

# %%
users['Gender'].replace({'Female': 'F', 'Male': 'M'}, inplace=True)
users.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  Tenure  \
# 0          1    15634602  Hargrave          619    France      F   42       2
# 1          2    15647311      Hill          608     Spain      F   41       1
# 2          3    15619304      Onio          502    France      F   42       8
# 3          4    15701354      Boni          699    France      F   39       1
# 4          5    15737888  Mitchell          850     Spain      F   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  new_feature  Age (days)  Age (days) 2  Age (days) 3  target
# 0       1            0       15330         15330         15330       1
# 1       0            0       14965         14965         14965       0
# 2       1            0       15330         15330         15330       1
# 3       0            0       14235         14235         14235       1
# 4       0            0       15695         15695         15695       0

# %% [markdown]
# ### Методы агрегации

# %% [markdown]
# Агрегация, или агрегирование — процесс объединения элементов в одно значение<br>
# Первый способ - вызвать метод agg() у pd.Series и передать в него список желаемых агрегаций

# %%
users['Age'].agg(['min', 'max'])
# Out:
# min    18
# max    92
# Name: Age, dtype: int64

# %%
users.agg({
    'Age': ['min', 'max'],
    'EstimatedSalary': 'mean'
})
# Out:
#        Age  EstimatedSalary
# min   18.0              NaN
# max   92.0              NaN
# mean   NaN    100090.239881

# %%
users.agg(
    min_age=('Age', 'min'),
    max_age=('Age', 'max'),
    mean_salary=('EstimatedSalary', 'mean')
)
# Out:
#               Age  EstimatedSalary
# min_age      18.0              NaN
# max_age      92.0              NaN
# mean_salary   NaN    100090.239881

# %% [markdown]
# ### Методы объединения

# %% [markdown]
# [file](https://gbcdn.mrgcdn.ru/uploads/asset/4239332/attachment/7d8be3cf1f6192275f44c62047e51fc7.html)

# %% [markdown]
# ```bank = pd.read_csv('bank.csv', sep=';')```

# %% [markdown]
# ```bank.shape```

# %% [markdown]
# ```merged = users.merge(bank, left_on='CustomerId', right_on='CustomerId') ```

# %% [markdown]
# ```users_id = users.set_index('CustomerId')```

# %% [markdown]
# ```bank_id = bank.set_index('CustomerId')```

# %% [markdown]
# ```bank_id.join(users_id).head()```

# %% [markdown]
# ```bank_id.join(users_id).reset_index().head()```

# %% [markdown]
# ### Атрибут how

# %% [markdown]
# <img src ='./how.jpg'>

# %%
toy_df1 = pd.DataFrame({
    'col_1': [1, 2, 3],
    'col_2': [9, 9, 9]
})

toy_df2 = pd.DataFrame({
    'col_1': [3, 4],
    'col_3': [0, 0]
})

display(toy_df1, toy_df2)
# Out:
#    col_1  col_2
# 0      1      9
# 1      2      9
# 2      3      9
#    col_1  col_3
# 0      3      0
# 1      4      0

# %%
toy_df1.merge(toy_df2, how='left')
# Out:
#    col_1  col_2  col_3
# 0      1      9    NaN
# 1      2      9    NaN
# 2      3      9    0.0

# %%
toy_df1.merge(toy_df2, how='right')
# Out:
#    col_1  col_2  col_3
# 0      3    9.0      0
# 1      4    NaN      0

# %%
toy_df1.merge(toy_df2, how='inner')
# Out:
#    col_1  col_2  col_3
# 0      3      9      0

# %%
toy_df1.merge(toy_df2, how='outer')
# Out:
#    col_1  col_2  col_3
# 0      1    9.0    NaN
# 1      2    9.0    NaN
# 2      3    9.0    0.0
# 3      4    NaN    0.0

# %% [markdown]
# left

# %% [markdown]
# ```merged_left = bank.merge(users, on='CustomerId', how='left')```

# %% [markdown]
# ```merged_right.isna().sum()```

# %% [markdown]
# ```merged_right[merged_right['CreditScore'].isna()]```

# %% [markdown]
# ```bank[bank['CustomerId'] == 15611325]```

# %% [markdown]
# inner

# %% [markdown]
# ```merged_inner = bank.merge(users, on='CustomerId', how='inner')```

# %% [markdown]
# ```merged_inner.isna().sum()```

# %% [markdown]
# outer

# %% [markdown]
# ```merged_outer = bank.merge(users, on='CustomerId', how='outer')```

# %% [markdown]
# ```merged_outer.isna().sum()```

# %% [markdown]
# ### Методы группировок

# %% [markdown]
# <img src = './groupby.webp'>

# %%
toy_df = pd.DataFrame({
    'client_id': [1, 2, 2, 3, 1, 1],
    'item': ['chocolate', 'cheese', 'ham', 'candy', 'chair', 'book'],
    'price': [68, 280, 302, 39, 2099, 1089]
})

toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
grouped = toy_df.groupby('client_id')
grouped

# %%
grouped.groups
# Out:
# {1: [0, 4, 5], 2: [1, 2], 3: [3]}

# %%
grouped.sum()
# Out:
#                          item  price
# client_id
# 1          chocolatechairbook   3256
# 2                   cheeseham    582
# 3                       candy     39

# %%
grouped.agg({'price': ['sum', 'min', 'max']})
# Out:
#           price
#             sum  min   max
# client_id
# 1          3256   68  2099
# 2           582  280   302
# 3            39   39    39

# %%
users.groupby('Geography').agg({'Age': ['mean'], 'EstimatedSalary': ['min']})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511767           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %% [markdown]
# pivot_table

# %%
toy_df
# Out:
#    client_id       item  price
# 0          1  chocolate     68
# 1          2     cheese    280
# 2          2        ham    302
# 3          3      candy     39
# 4          1      chair   2099
# 5          1       book   1089

# %%
toy_df.pivot_table(index='client_id',
                   values='price',
                   aggfunc='sum')
# Out:
#            price
# client_id
# 1           3256
# 2            582
# 3             39

# %%
users.pivot_table(index='Geography',
                  aggfunc={'Age': ['mean'], 'EstimatedSalary': 'min'})
# Out:
#                  Age EstimatedSalary
#                 mean             min
# Geography
# France     38.511767           90.07
# Germany    39.771622           11.58
# Spain      38.890997          417.41

# %%
users.pivot_table(index='Geography',
                  columns='Gender', 
                  values='EstimatedSalary',
                  aggfunc='mean',
                  margins=True,
                  margins_name='Total')
# Out:
# Gender                 F              M          Total
# Geography
# France      99564.252755  100174.252495   99899.180814
# Germany    102446.424124   99905.033959  101113.435102
# Spain      100734.107475   98425.687680   99440.572281
# Total      100601.541382   99664.576931  100090.239881

# %% [markdown]
# crosstab

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'])
# Out:
# Gender        F     M
# Geography
# France     2261  2753
# Germany    1193  1316
# Spain      1089  1388

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'],
            values=users['EstimatedSalary'],
            aggfunc='mean')
# Out:
# Gender                 F              M
# Geography
# France      99564.252755  100174.252495
# Germany    102446.424124   99905.033959
# Spain      100734.107475   98425.687680

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'],
            normalize='all')
# Out:
# Gender          F       M
# Geography
# France     0.2261  0.2753
# Germany    0.1193  0.1316
# Spain      0.1089  0.1388

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'],
            normalize='index')
# Out:
# Gender            F         M
# Geography
# France     0.450937  0.549063
# Germany    0.475488  0.524512
# Spain      0.439645  0.560355

# %%
pd.crosstab(index=users['Geography'],
            columns=users['Gender'],
            normalize='columns')
# Out:
# Gender            F         M
# Geography
# France     0.497689  0.504490
# Germany    0.262602  0.241158
# Spain      0.239709  0.254352

# %% [markdown]
# ### Встроенные визуализации

# %%
users['Age'].hist();
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 users['Age'].hist();
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:98, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      35 def hist_series(
#      36     self,
#      37     by=None,
#    (...)
#      48     **kwargs,
#      49 ):
#      50     """
#      51     Draw histogram of the input series using matplotlib.
#      52
#    (...)
#      96     matplotlib.axes.Axes.hist : Plot a histogram using matplotlib.
#      97     """
# ---> 98     plot_backend = _get_plot_backend(backend)
#      99     return plot_backend.hist_series(
#     100         self,
#     101         by=by,
#    (...)
#     111         **kwargs,
#     112     )
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1862, in _get_plot_backend(backend)
#    1859 if backend_str in _backends:
#    1860     return _backends[backend_str]
# -> 1862 module = _load_backend(backend_str)
#    1863 _backends[backend_str] = module
#    1864 return module
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1794, in _load_backend(backend)
#    1792         module = importlib.import_module("pandas.plotting._matplotlib")
#    1793     except ImportError:
# -> 1794         raise ImportError(
#    1795             "matplotlib is required for plotting when the "
#    1796             'default backend "matplotlib" is selected.'
#    1797         ) from None
#    1798     return module
#    1800 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
data = users.groupby('Gender').count()['Age']
data.name = 'Gender'
data
# Out:
# Gender
# F    4543
# M    5457
# Name: Gender, dtype: int64

# %%
data.plot.pie(y='Gender');
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 data.plot.pie(y='Gender');
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1589, in PlotAccessor.pie(self, **kwargs)
#    1583 if (
#    1584     isinstance(self._parent, ABCDataFrame)
#    1585     and kwargs.get("y", None) is None
#    1586     and not kwargs.get("subplots", False)
#    1587 ):
#    1588     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1589 return self(kind="pie", **kwargs)
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:895, in PlotAccessor.__call__(self, *args, **kwargs)
#     894 def __call__(self, *args, **kwargs):
# --> 895     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     897     x, y, kind, kwargs = self._get_call_args(
#     898         plot_backend.__name__, self._parent, args, kwargs
#     899     )
#     901     kind = self._kind_aliases.get(kind, kind)
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1862, in _get_plot_backend(backend)
#    1859 if backend_str in _backends:
#    1860     return _backends[backend_str]
# -> 1862 module = _load_backend(backend_str)
#    1863 _backends[backend_str] = module
#    1864 return module
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1794, in _load_backend(backend)
#    1792         module = importlib.import_module("pandas.plotting._matplotlib")
#    1793     except ImportError:
# -> 1794         raise ImportError(
#    1795             "matplotlib is required for plotting when the "
#    1796             'default backend "matplotlib" is selected.'
#    1797         ) from None
#    1798     return module
#    1800 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
users.iloc[:100].plot.scatter(x='Age', y='EstimatedSalary');
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 users.iloc[:100].plot.scatter(x='Age', y='EstimatedSalary');
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1674, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1591 def scatter(self, x, y, s=None, c=None, **kwargs) -> PlotAccessor:
#    1592     """
#    1593     Create a scatter plot with varying marker point size and color.
#    1594
#    (...)
#    1672         ...                       colormap='viridis')
#    1673     """
# -> 1674     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:895, in PlotAccessor.__call__(self, *args, **kwargs)
#     894 def __call__(self, *args, **kwargs):
# --> 895     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     897     x, y, kind, kwargs = self._get_call_args(
#     898         plot_backend.__name__, self._parent, args, kwargs
#     899     )
#     901     kind = self._kind_aliases.get(kind, kind)
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1862, in _get_plot_backend(backend)
#    1859 if backend_str in _backends:
#    1860     return _backends[backend_str]
# -> 1862 module = _load_backend(backend_str)
#    1863 _backends[backend_str] = module
#    1864 return module
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1794, in _load_backend(backend)
#    1792         module = importlib.import_module("pandas.plotting._matplotlib")
#    1793     except ImportError:
# -> 1794         raise ImportError(
#    1795             "matplotlib is required for plotting when the "
#    1796             'default backend "matplotlib" is selected.'
#    1797         ) from None
#    1798     return module
#    1800 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
data = users.groupby('Tenure').count()['Balance']
data.name = 'num_clients'
data
# Out:
# Tenure
# 0      413
# 1     1035
# 2     1048
# 3     1009
# 4      989
# 5     1012
# 6      967
# 7     1028
# 8     1025
# 9      984
# 10     490
# Name: num_clients, dtype: int64

# %%
data.plot.bar(width=0.8);
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 data.plot.bar(width=0.8);
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1136, in PlotAccessor.bar(self, x, y, **kwargs)
#    1046 @Appender(
#    1047     """
#    1048     See Also
#    (...)
#    1125     self, x=None, y=None, **kwargs
#    1126 ) -> PlotAccessor:
#    1127     """
#    1128     Vertical bar plot.
#    1129
#    (...)
#    1134     other axis represents a measured value.
#    1135     """
# -> 1136     return self(kind="bar", x=x, y=y, **kwargs)
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:895, in PlotAccessor.__call__(self, *args, **kwargs)
#     894 def __call__(self, *args, **kwargs):
# --> 895     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     897     x, y, kind, kwargs = self._get_call_args(
#     898         plot_backend.__name__, self._parent, args, kwargs
#     899     )
#     901     kind = self._kind_aliases.get(kind, kind)
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1862, in _get_plot_backend(backend)
#    1859 if backend_str in _backends:
#    1860     return _backends[backend_str]
# -> 1862 module = _load_backend(backend_str)
#    1863 _backends[backend_str] = module
#    1864 return module
#
# File c:\Users\mrrom\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1794, in _load_backend(backend)
#    1792         module = importlib.import_module("pandas.plotting._matplotlib")
#    1793     except ImportError:
# -> 1794         raise ImportError(
#    1795             "matplotlib is required for plotting when the "
#    1796             'default backend "matplotlib" is selected.'
#    1797         ) from None
#    1798     return module
#    1800 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
